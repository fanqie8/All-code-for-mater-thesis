# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_excel(r'C:\Users\dawns\Desktop\Master thesis\data\Dataset_L1 learner_clean.xlsx',index_col=None, header=0)

# %%
train_data
# Out:
#                                     id student_id       title  \
# 0     f207dc5aa89511eaa65b54e1ad63dcde       5139      不容易的林楠
# 1     f20a75c4a89511eaa65b54e1ad63dcde       2106     我是一只小兔子
# 2     f20d440fa89511eaa65b54e1ad63dcde       2311      我是一只老虎
# 3     f20faf5ba89511eaa65b54e1ad63dcde       2232     我是一只小猴子
# 4     f21246a9a89511eaa65b54e1ad63dcde       3338  第五十一变的有趣经历
# ...                                ...        ...         ...
# 8313  26d44fb3a94711eaa65b54e1ad63dcde       1247       小鸭和小鸡
# 8314  26d538cfa94711eaa65b54e1ad63dcde       1248         救小鸡
# 8315  26d63508a94711eaa65b54e1ad63dcde       1249       小鸡救小鸭
# 8316  26d71675a94711eaa65b54e1ad63dcde       1250       小鸡救小鸭
# 8317  26d7f495a94711eaa65b54e1ad63dcde       1251         救小鸭
#
#                                                 content create_time  \
# 0     林楠是一个从农村转到这所学校的，家庭条件很不好。刚去面试的时候，校长对林楠的印象很不好，林楠...  2019-07-01
# 1     我是一只小兔子，我的伙伴说当一只小兔子一点也不好，因为一不小心就会被大灰狼吃掉的，你觉得得当...  2019-07-01
# ...

# %%
train_data.sample(n=3668)
# Out:
#                                     id student_id       title  \
# 1178  0dba4167a89611eaa65b54e1ad63dcde       3328    想要自由的小猴子
# 5308  09b6494fa93811eaa65b54e1ad63dcde       2120        妈妈的爱
# 1553  112e5c33a89611eaa65b54e1ad63dcde       1220    假如我是个布娃娃
# 300   f5255fe5a89511eaa65b54e1ad63dcde       3143  第五十一变的有趣经历
# 6949  11882313a93f11eaa65b54e1ad63dcde       2207    秋天来到我身边。
# ...                                ...        ...         ...
# 6686  a99097a2a93c11eaa65b54e1ad63dcde       3441       地球人的信
# 2646  4a4df777a89b11eaa65b54e1ad63dcde       2120   小刺猬给小熊的称赞
# 2491  490bb85ca89b11eaa65b54e1ad63dcde       1138          过桥
# 6101  a623bec0a93c11eaa65b54e1ad63dcde       1136      聪明的小刺猬
# 3078  4dcb1fe0a89b11eaa65b54e1ad63dcde       5241   地球上的最后一个人
#
#                                                 content create_time  \
# 1178  小猴子离开动物园之前，还吃了点东西，小猴子吃完，就赶紧往旁边的树林跑去。\n小猴子跑啊跑啊，...  2018-12-21
# 5308  在一个秋天的早晨，微风会轻轻地吹着，好像在悠闲地走着，每一天都天气晴朗，阳光明媚，天上飘着几...  2015-12-22
# ...

# %%
random= pd.DataFrame()
random = train_data.sample(n=3668)

# %%
random.to_excel(r'C:\Users\dawns\Desktop\Master thesis\data\L1_randomselect.xlsx')
